# %%
import pandas as pd

df_final_data = pd.read_csv('/Users/joshstrupp/Documents/Working/Educational/MSDV/ms1-final/notebook_explore/notebooks/final_data.csv')
df_final_data.head()
# Out:
#                                                Title  \
# 0  Lillian Evanti wears costume from Lucia di Lam...
# 1                        Angola Costume de Benguella
# 2                   O chefe Cahuima e filhos (Hollo)
# 3                                   Angolan Children
# 4                      Algeria Chambba et son Méhari
#
#                            Museum  \
# 0      Anacostia Community Museum
# 1  National Museum of African Art
# 2  National Museum of African Art
# 3  National Museum of African Art
# 4  National Museum of African Art
#
#                                                Names  \
# 0  ['Evanti, Lillian, Mme. (Lillian Evans Tibbs),...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                              Collection Photographer  \
# ...
